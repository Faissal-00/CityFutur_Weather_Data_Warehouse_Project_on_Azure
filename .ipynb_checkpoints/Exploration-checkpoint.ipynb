# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
date=pd.read_csv('datedim.csv',encoding='UTF-8')
date
# Out:
#      DateID        Date
# 0         1  2010-01-01
# 1         2  2010-01-02
# 2         3  2010-01-03
# 3         4  2010-01-04
# 4         5  2010-01-05
# ..      ...         ...
# 725     726  2011-12-27
# 726     727  2011-12-28
# 727     728  2011-12-29
# 728     729  2011-12-30
# 729     730  2011-12-31
#
# [730 rows x 2 columns]

# %%
region=pd.read_csv('regiondim.csv',encoding='UTF-8')
region
# Out:
#    RegionID RegionName
# 0         1      North
# 1         2      South
# 2         3       East
# 3         4       West
# 4         5    Central

# %%
weathermetrics=pd.read_csv('weathermetrics.csv',encoding='UTF-8')
weathermetrics
# Out:
#       DateID  RegionID  AverageTemperature  Humidity  WindSpeed  Rainfall
# 0          1         1                  21        98          5         2  \
# 1          1         2                  35        19         27         7
# 2          1         3                  13        82          0         6
# 3          1         4                  27        69         18         5
# 4          1         5                   2        16         30         9
# ...      ...       ...                 ...       ...        ...       ...
# 3645     730         1                   4        86         25         3
# 3646     730         2                  18         7         22         3
# 3647     730         3                  11        61          8         5
# 3648     730         4                  39        12         30         6
# 3649     730         5                  37        51         23         5
#
#       SunshineHours
# 0                 0
# 1                18
# 2                 4
# 3                 1
# 4                 1
# ...             ...
# 3645              6
# 3646             10
# 3647             19
# 3648             19
# 3649             12
#
# [3650 rows x 7 columns]

# %%
df.describe()
# Out:
#         CustomerID          Age    ProductID        Price       Weight
# count  9999.000000  9999.000000  9999.000000  9999.000000  9999.000000  \
# mean   4999.000000    44.445545    10.851085   500.500877    25.366433
# std    2886.607005    16.238477    11.452692   284.881788    14.327457
# min       0.000000    -7.000000     0.000000     5.020000     0.500000
# 25%    2499.500000    31.000000     3.000000   254.710000    12.770000
# 50%    4999.000000    44.000000     9.000000   501.010000    25.480000
# 75%    7498.500000    57.000000    13.000000   746.345000    37.785000
# max    9998.000000   191.000000    48.000000   999.830000    50.000000
#
#            OrderID  InventoryID   StockLevel  RestockThreshold  WarehouseID
# count  9999.000000  9999.000000  9999.000000       9999.000000  9999.000000  \
# mean   4999.000000  4999.000000   498.626963        253.219222   248.341434
# std    2886.607005  2886.607005   290.985261        141.788026   143.145750
# min       0.000000     0.000000     1.000000         10.000000     0.000000
# 25%    2499.500000  2499.500000   244.000000        129.000000   125.000000
# 50%    4999.000000  4999.000000   491.000000        252.000000   249.000000
# 75%    7498.500000  7498.500000   756.000000        375.000000   371.000000
# max    9998.000000  9998.000000  1000.000000        500.000000   499.000000
#
#           Capacity   SupplierID  QualityScore
# count   9999.00000  9999.000000   8960.000000
# mean   12444.90179     4.490449      5.850890
# std     4279.76558     2.882004      2.862797
# min     5037.00000     0.000000      1.230000
# 25%     8821.00000     2.000000      2.480000
# 50%    12771.00000     5.000000      6.820000
# 75%    15936.00000     7.000000      7.810000
# max    19980.00000     9.000000      9.830000

# %%
print(df.isnull().sum(axis=0))
# Out:
# CustomerID               0
# Name                     0
# Email                  100
# Age                      0
# Gender                   0
# Location                 0
# ProductID                0
# Category                 0
# Subcategory              0
# Price                    0
# Weight                   0
# Dimensions               0
# OrderID                  0
# Date_Order               0
# TotalAmount              0
# ShippingMethod           0
# Status                   0
# InventoryID              0
# StockLevel               0
# RestockThreshold         0
# LastRestockDate          0
# WarehouseID              0
# Location_warehouse       0
# Capacity                 0
# SupplierID               0
# Company                  0
# Location_Supplier        0
# QualityScore          1039
# dtype: int64

# %%
# Create a condition to filter rows
condition = (df['Age'] < 13) | (df['Age'] > 87)

# Apply the condition to the DataFrame and count the rows
count_of_rows = len(df[condition])

print("Number of rows with age < 13 or age > 87:", count_of_rows)
# Out:
# Number of rows with age < 13 or age > 87: 40

# %%
columns=df.columns.tolist()
df[columns[:14]]
# Out:
#       CustomerID              Name                      Email  Age  Gender
# 0              0      Kayla Howell                        NaN  112    Male  \
# 1              1      Wanda Graham    brianfisher@example.com   65  Female
# 2              2     Raymond James      brownfred@example.com   21    Male
# 3              3      Thomas Smith    anthonyleon@example.com   68  Female
# 4              4       Matthew Lee        david54@example.org   66  Female
# ...          ...               ...                        ...  ...     ...
# 9994        9994  Jeffrey Martinez   deborahowens@example.org   21  Female
# 9995        9995    Justin Johnson         fmoore@example.net   45  Female
# 9996        9996       Andrew Frye  coopermallory@example.com   43  Female
# 9997        9997      Miguel Allen   allenmichael@example.com   53    Male
# 9998        9998  Brenda Patterson       jaclyn36@example.com   39    Male
#
#               Location  ProductID      Category    Subcategory   Price
# 0        Lake Benjamin          0  Electronics©  Smart Watches  384.37  \
# 1          West Joshua          1   Electronics        Cameras  331.40
# 2           Sweeneyton          2   Electronics  Mobile Phones  534.75
# 3         Lake Matthew          3     Furniture       Cabinets  259.52
# 4     West Kristinbury          4      Clothing       T-Shirts  800.64
# ...                ...        ...           ...            ...     ...
# 9994       Johnborough         12      Clothing        Dresses  923.74
# 9995    West Pennyside          4      Clothing       T-Shirts  689.97
# 9996      East Roberto         10   Electronics        Laptops    7.06
# 9997       Sanchezfort          1   Electronics        Cameras  767.67
# 9998        Justinstad          2   Electronics  Mobile Phones  171.45
#
#       Weight Dimensions  OrderID  Date_Order
# 0      16.16   33x13x47        0  2021-08-04
# 1      21.85    8x49x50        1  03-08-2021
# 2      40.74    6x30x30        2  2020-10-21
# 3      11.76    23x27x1        3  04-07-2022
# 4      13.83   26x21x15        4  11/05/2022
# ...      ...        ...      ...         ...
# 9994   17.74   27x10x36     9994  12-23-2020
# 9995   47.39   23x23x43     9995  03/08/2022
# 9996   44.54   50x46x18     9996  08-16-2021
# 9997    4.96   15x34x19     9997  2020-09-21
# 9998    7.71   11x44x23     9998  2021-08-18
#
# [9999 rows x 14 columns]

# %%
import pandas as pd

# Assuming you have your data loaded into a DataFrame called 'df'
# Check for duplicate 'ProductID' values
duplicates = df[df.duplicated('ProductID', keep=False)]
duplicates
# Out:
#       CustomerID              Name                      Email  Age  Gender
# 0              0      Kayla Howell                        NaN  112    Male  \
# 1              1      Wanda Graham    brianfisher@example.com   65  Female
# 2              2     Raymond James      brownfred@example.com   21    Male
# 3              3      Thomas Smith    anthonyleon@example.com   68  Female
# 4              4       Matthew Lee        david54@example.org   66  Female
# ...          ...               ...                        ...  ...     ...
# 9994        9994  Jeffrey Martinez   deborahowens@example.org   21  Female
# 9995        9995    Justin Johnson         fmoore@example.net   45  Female
# 9996        9996       Andrew Frye  coopermallory@example.com   43  Female
# 9997        9997      Miguel Allen   allenmichael@example.com   53    Male
# 9998        9998  Brenda Patterson       jaclyn36@example.com   39    Male
#
#               Location  ProductID      Category    Subcategory   Price  ...
# 0        Lake Benjamin          0  Electronics©  Smart Watches  384.37  ...  \
# 1          West Joshua          1   Electronics        Cameras  331.40  ...
# 2           Sweeneyton          2   Electronics  Mobile Phones  534.75  ...
# 3         Lake Matthew          3     Furniture       Cabinets  259.52  ...
# 4     West Kristinbury          4      Clothing       T-Shirts  800.64  ...
# ...                ...        ...           ...            ...     ...  ...
# 9994       Johnborough         12      Clothing        Dresses  923.74  ...
# 9995    West Pennyside          4      Clothing       T-Shirts  689.97  ...
# 9996      East Roberto         10   Electronics        Laptops    7.06  ...
# 9997       Sanchezfort          1   Electronics        Cameras  767.67  ...
# 9998        Justinstad          2   Electronics  Mobile Phones  171.45  ...
#
#       StockLevel RestockThreshold  LastRestockDate WarehouseID
# 0            862               25       2022-03-06          54  \
# 1            549              254       2020-11-23           6
# 2            656              236       2022-02-10         236
# 3            621               88       2021-07-04         239
# 4            557              385       2022-08-16         289
# ...          ...              ...              ...         ...
# 9994         726              120       2021-03-04         482
# 9995          84              254       2020-11-19         180
# 9996         369              177       2020-11-27          52
# 9997         966              149       2022-08-20         106
# 9998         619              327       2020-09-09         328
#
#        Location_warehouse Capacity SupplierID                   Company
# 0            Jasonborough    15745          2            Miller-Pearson  \
# 1                Dawnport     7291          2            Miller-Pearson
# 2                Hallview    10609          8            Parks-Gallegos
# 3             Mckenzieton    16255          5                Morgan LLC
# 4             Port Austin    16559          2            Miller-Pearson
# ...                   ...      ...        ...                       ...
# 9994           Mendezside    18674          2            Miller-Pearson
# 9995            Scottfort    12059          3         Johnson-Rodriguez
# 9996           North Mary    19446          1  Salas, Gonzalez and Todd
# 9997          New Melanie     6702          1  Salas, Gonzalez and Todd
# 9998  North Jenniferburgh    10835          6                Morgan LLC
#
#       Location_Supplier  QualityScore
# 0            Clarkmouth          9.83
# 1            Clarkmouth          9.83
# 2           Jenkinsside          6.82
# 3       Port Robynmouth          1.23
# 4            Clarkmouth          9.83
# ...                 ...           ...
# 9994         Clarkmouth          9.83
# 9995   Katherineborough          7.40
# 9996       Patriciaberg          8.21
# 9997       Patriciaberg          8.21
# 9998       New Marktown          2.48
#
# [9999 rows x 28 columns]

# %%
com = df['ProductID'].nunique()
com
# Out:
# 15

# %%
uni = df.groupby('ProductID')['Price'].unique()
uni
# Out:
# ProductID
# 0     [384.37, 851.75, 513.1, 609.85, 467.85, 217.56...
# 1     [331.4, 47.35, 119.71, 330.88, 796.36, 414.21,...
# 2     [534.75, 319.88, 867.3, 952.27, 140.13, 180.06...
# 3     [259.52, 511.68, 433.85, 146.18, 702.29, 680.7...
# 4     [800.64, 517.0, 648.32, 550.82, 125.76, 42.33,...
# 6     [509.78, 55.02, 177.16, 194.07, 720.86, 563.05...
# 8     [85.79, 29.0, 437.44, 351.97, 593.75, 397.96, ...
# 9     [43.71, 479.38, 377.97, 737.52, 910.48, 356.04...
# 10    [63.67, 942.14, 941.25, 895.95, 299.45, 747.97...
# 11    [514.67, 446.11, 360.44, 272.87, 468.03, 823.1...
# 12    [692.54, 647.51, 233.1, 967.73, 696.51, 416.74...
# 13    [899.24, 428.18, 588.66, 903.11, 339.76, 77.08...
# 16    [120.26, 455.83, 473.64, 578.14, 147.75, 41.78...
# 21    [541.9, 40.55, 321.05, 73.5, 115.53, 817.36, 8...
# 48    [399.79, 886.11, 496.17, 718.89, 126.51, 372.7...
# Name: Price, dtype: object

# %%
uni = df.groupby('WarehouseID')['InventoryID'].unique()
uni
# Out:
# WarehouseID
# 0      [223, 485, 526, 1104, 1275, 2500, 2579, 2802, ...
# 1      [30, 47, 2652, 2892, 3207, 3974, 4071, 4214, 5...
# 2      [1319, 1747, 1956, 2194, 2974, 3404, 3613, 425...
# 3      [1248, 2562, 3697, 4315, 4343, 4568, 4728, 485...
# 4      [787, 2066, 2200, 3233, 4250, 4655, 4988, 5588...
#                              ...
# 495    [611, 973, 3869, 4449, 5173, 6753, 7090, 7681,...
# 496    [279, 340, 1563, 3334, 3743, 3903, 4847, 5644,...
# 497    [136, 2323, 2489, 2556, 2681, 3433, 3848, 5687...
# 498    [413, 709, 1232, 2591, 3240, 4370, 4514, 4787,...
# 499    [630, 1059, 1095, 1447, 1663, 1820, 2138, 2371...
# Name: InventoryID, Length: 500, dtype: object

# %%
uni = df.groupby('WarehouseID')['InventoryID'].unique()
uni
# Out:
# WarehouseID
# 0      [223, 485, 526, 1104, 1275, 2500, 2579, 2802, ...
# 1      [30, 47, 2652, 2892, 3207, 3974, 4071, 4214, 5...
# 2      [1319, 1747, 1956, 2194, 2974, 3404, 3613, 425...
# 3      [1248, 2562, 3697, 4315, 4343, 4568, 4728, 485...
# 4      [787, 2066, 2200, 3233, 4250, 4655, 4988, 5588...
#                              ...
# 495    [611, 973, 3869, 4449, 5173, 6753, 7090, 7681,...
# 496    [279, 340, 1563, 3334, 3743, 3903, 4847, 5644,...
# 497    [136, 2323, 2489, 2556, 2681, 3433, 3848, 5687...
# 498    [413, 709, 1232, 2591, 3240, 4370, 4514, 4787,...
# 499    [630, 1059, 1095, 1447, 1663, 1820, 2138, 2371...
# Name: InventoryID, Length: 500, dtype: object

# %%
columns=df.columns.tolist()
df[columns[14:]]
# Out:
#      TotalAmount ShippingMethod     Status  InventoryID  StockLevel
# 0        £280.09        Express    Pending            0         862  \
# 1        £740.51        Two-day  Cancelled            1         549
# 2       $1560.72        Two-day  Cancelled            2         656
# 3       $1876.08        Express    Pending            3         621
# 4        £170.67       Standard    Pending            4         557
# ...          ...            ...        ...          ...         ...
# 9994    €2371.77        Two-day  Delivered         9994         726
# 9995    €1517.88        Two-day    Shipped         9995          84
# 9996     €216.89        Express  Cancelled         9996         369
# 9997    $1409.02        Two-day    Pending         9997         966
# 9998     $114.92        Two-day  Delivered         9998         619
#
#       RestockThreshold LastRestockDate  WarehouseID   Location_warehouse
# 0                   25      2022-03-06           54         Jasonborough  \
# 1                  254      2020-11-23            6             Dawnport
# 2                  236      2022-02-10          236             Hallview
# 3                   88      2021-07-04          239          Mckenzieton
# 4                  385      2022-08-16          289          Port Austin
# ...                ...             ...          ...                  ...
# 9994               120      2021-03-04          482           Mendezside
# 9995               254      2020-11-19          180            Scottfort
# 9996               177      2020-11-27           52           North Mary
# 9997               149      2022-08-20          106          New Melanie
# 9998               327      2020-09-09          328  North Jenniferburgh
#
#       Capacity  SupplierID                   Company Location_Supplier
# 0        15745           2            Miller-Pearson        Clarkmouth  \
# 1         7291           2            Miller-Pearson        Clarkmouth
# 2        10609           8            Parks-Gallegos       Jenkinsside
# 3        16255           5                Morgan LLC   Port Robynmouth
# 4        16559           2            Miller-Pearson        Clarkmouth
# ...        ...         ...                       ...               ...
# 9994     18674           2            Miller-Pearson        Clarkmouth
# 9995     12059           3         Johnson-Rodriguez  Katherineborough
# 9996     19446           1  Salas, Gonzalez and Todd      Patriciaberg
# 9997      6702           1  Salas, Gonzalez and Todd      Patriciaberg
# 9998     10835           6                Morgan LLC      New Marktown
#
#       QualityScore
# 0             9.83
# 1             9.83
# 2             6.82
# 3             1.23
# 4             9.83
# ...            ...
# 9994          9.83
# 9995          7.40
# 9996          8.21
# 9997          8.21
# 9998          2.48
#
# [9999 rows x 14 columns]

# %%
name = df[df['ShippingMethode'] == 'Nan']
name
# Out:
#       CustomerID             Name                       Email  Age  Gender
# 21            21    Amanda Hanson        iwheeler@example.net   65    Male  \
# 26            26        Mary Ross       gregory22@example.com   69    Male
# 49            49    Jaime Chapman        ashley20@example.org   23    Male
# 50            50     Paul Schmidt         jason64@example.org   23    Male
# 56            56       Erin Ellis      rothronnie@example.com   64    Male
# ...          ...              ...                         ...  ...     ...
# 9924        9924    Ethan Bradley     christian82@example.org   62    Male
# 9940        9940   Bethany Castro     kimsandoval@example.com   50  Female
# 9964        9964  Frederick Scott     cherrymaria@example.org   24  Female
# 9965        9965   Erin Barnes MD         aaron22@example.com   54  Female
# 9989        9989       Todd Smith  hunterbenjamin@example.com   21  Female
#
#              Location  ProductID   Category Subcategory   Price  ...
# 21           New Sean         21  Furniture       Sofas  541.90  ...  \
# 26           Leemouth         21  Furniture       Sofas   40.55  ...
# 49    South Katherine         21  Furniture       Sofas  321.05  ...
# 50         Greenburgh         21  Furniture       Sofas   73.50  ...
# 56        Tabithaport         21  Furniture       Sofas  115.53  ...
# ...               ...        ...        ...         ...     ...  ...
# 9924        Davidberg         21  Furniture       Sofas  640.63  ...
# 9940  West Geraldside         21  Furniture       Sofas  539.66  ...
# 9964      Krauseburgh         21  Furniture       Sofas  486.82  ...
# 9965       New Andrea         21  Furniture       Sofas  743.18  ...
# 9989     Mitchellberg         21  Furniture       Sofas  307.57  ...
#
#       StockLevel RestockThreshold  LastRestockDate WarehouseID
# 21           835              100       2021-12-04          95  \
# 26           602              276       2021-04-10          18
# 49            99              283       2021-07-14         164
# 50           453              328       2021-05-11         268
# 56           418              127       2021-03-09         302
# ...          ...              ...              ...         ...
# 9924         115              260       2021-03-18         194
# 9940         616              132       2022-06-01         357
# 9964          60              205       2021-10-14         438
# 9965         385              279       2022-04-23         317
# 9989         833              125       2021-01-12         281
#
#      Location_warehouse Capacity SupplierID                   Company
# 21         Lake Monique    18830          5                Morgan LLC  \
# 26      West Jasonshire    14204          1  Salas, Gonzalez and Todd
# 49           Austinland     7259          1  Salas, Gonzalez and Todd
# 50            Chasefurt    16822          0         Johnson-Rodriguez
# 56           Nathanland    17898          6                Morgan LLC
# ...                 ...      ...        ...                       ...
# 9924       Daniellefurt    15629          3         Johnson-Rodriguez
# 9940          Gomeztown    17698          8            Parks-Gallegos
# 9964   South Ashleyland    14465          5                Morgan LLC
# 9965         Aaronmouth    11416          1  Salas, Gonzalez and Todd
# 9989          Hoganfort    15078          1  Salas, Gonzalez and Todd
#
#       Location_Supplier  QualityScore
# 21      Port Robynmouth          1.23
# 26         Patriciaberg          8.21
# 49         Patriciaberg          8.21
# 50      Port Robynmouth           NaN
# 56         New Marktown          2.48
# ...                 ...           ...
# 9924   Katherineborough          7.40
# 9940        Jenkinsside          6.82
# 9964    Port Robynmouth          1.23
# 9965       Patriciaberg          8.21
# 9989       Patriciaberg          8.21
#
# [720 rows x 28 columns]

# %%
unique_values_count = df['LocationWarehouse'].nunique()
unique_values_count
# Out:
# 491

# %%
duplicates = df[df['Location'].duplicated(keep=False)]

duplicate_names = duplicates['Location'].unique()

duplicates
# Out:
#       CustomerID               Name                       Email  Age  Gender
# 0           7659        Megan Myers   donnastephens@example.net   49    Male  \
# 2           2985     Willie Roberts         vwatson@example.net   64    Male
# 6           7578      Jessica Brown         ohowell@example.net   55    Male
# 7           3558    Michael Bonilla    rangelashley@example.org   42  Female
# 15           348    Marcus Robinson  pearsonmelissa@example.com   54  Female
# ...          ...                ...                         ...  ...     ...
# 4984        5051       Jerome Berry        ericholt@example.org   24    Male
# 4987        6949  Stephanie Lindsey        kjackson@example.org   24    Male
# 4988         769  Marilyn Mcconnell    latoyamiller@example.net   31  Female
# 4997        5390       James Romero    bryanderrick@example.com   35  Female
# 4998         860         Lori Green         vwagner@example.net   42  Female
#
#            Location  ProductID     Category    Subcategory   Price  ...
# 0      East Anthony          0  Electronics  Smart Watches  680.04  ...  \
# 2      Davidchester          4     Clothing       T-Shirts  355.64  ...
# 6      South Nathan          4     Clothing       T-Shirts  689.70  ...
# 7      East Anthony         16    Furniture         Tables  349.35  ...
# 15       Clarkmouth         48     Clothing          Jeans  587.90  ...
# ...             ...        ...          ...            ...     ...  ...
# 4984       New Dawn         21    Furniture          Sofas  269.76  ...
# 4987  Port Victoria         16    Furniture         Tables  706.41  ...
# 4988     Lake Jamie          0  Electronics  Smart Watches  853.22  ...
# 4997     Aaronville          6    Furniture         Chairs  992.18  ...
# 4998        Paulton          8     Clothing          Shoes  117.30  ...
#
#       StockLevel RestockThreshold  LastRestockDate WarehouseID
# 0             10              338       2021-03-21         220  \
# 2            246               39       2020-12-19          27
# 6            897              150       2022-05-27         204
# 7            676              320       2022-06-12         331
# 15           948               73       2021-03-31         359
# ...          ...              ...              ...         ...
# 4984           1              259       2021-11-16         220
# 4987         320              192       2022-05-21         332
# 4988          17              294       2022-07-20         301
# 4997         998              407       2022-05-20         192
# 4998         851              450       2022-05-07         136
#
#       LocationWarehouse Capacity SupplierID            Company
# 0            Lake Holly     9562          9  Johnson-Rodriguez  \
# 2              Colebury    16981          5         Morgan LLC
# 6     North Monicaville    14702          7       Miller Group
# 7            Julieshire     5795          2     Miller-Pearson
# 15     New Michaelhaven     9972          5         Morgan LLC
# ...                 ...      ...        ...                ...
# 4984         Lake Holly     9562          3  Johnson-Rodriguez
# 4987   East Richardview    18143          7       Miller Group
# 4988       Merrittshire     6520          7       Miller Group
# 4997           New Kyle    13661          9  Johnson-Rodriguez
# 4998       Jenniferfurt     7388          3  Johnson-Rodriguez
#
#       LocationSupplier  QualityScore
# 0     Katherineborough          7.81
# 2      Port Robynmouth          1.23
# 6           Clarkmouth          6.56
# 7           Clarkmouth          9.83
# 15     Port Robynmouth          1.23
# ...                ...           ...
# 4984  Katherineborough          7.40
# 4987        Clarkmouth          6.56
# 4988        Clarkmouth          6.56
# 4997  Katherineborough          7.81
# 4998  Katherineborough          7.40
#
# [1261 rows x 28 columns]

# %%
# aa=df['UserSegment'].unique()
# aa

# %%
# zero = df[df['Price'] == 0].shape
# zero

# %%
# zero = df[df['Quantity'] == 0]
# zero

# %%
# lap = df[df['Product Name'] == 'LaptopPro']
# lap

# %%
# # Sort the DataFrame by the 'Name' column
# df_sorted = df.sort_values(by='Name')
# df_sorted

# %%
# duplicates = df[df['Name'].duplicated(keep=False)]

# duplicate_names = duplicates['Name'].unique()

# filtered_rows = df[df['Name'].isin(duplicate_names)]

# filtered_rows

# %%
# import matplotlib.pyplot as plt
# # Replace 'Age' with the name of the column you want to check for outliers
# column_name = 'Price'

# # Create a scatter plot to visualize outliers
# plt.figure(figsize=(8, 6))
# plt.scatter(range(len(df[column_name])), df[column_name])
# plt.title(f'Scatter Plot of {column_name}')
# plt.xlabel('Index')
# plt.ylabel(column_name)
# plt.show()

# %%
# filtered_rows = df[df['Age'] < 100 ]
# filtered_rows

# %%
# columns_with_nan = df.columns[df.isnull().any()]

# print("Columns with NaN values:")
# print(columns_with_nan)

# %%
# import pandas as pd

# # Assuming you have a DataFrame named 'df'
# # Replace 'df' with your actual DataFrame name

# # Iterate through each column
# for column in df.columns:
#     # Check if any value in the column contains a hyphen
#     if df[column].astype(str).str.contains('-').any():
#         print(f"Column '{column}' contains values with a hyphen.")

# %%
# column_values = df['FullAddress']

# print(column_values)
